# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Key Data Structures In Pandas
# 1. Series : Is a labeled Array
# 2. DataFrame

# %%
s = pd.Series([1,2,3,4],index=['a','b','c','d'])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
df = pd.DataFrame({"Name":["Mehdi","Murtaza","Naqi"],
                   "Marks":[100,3,4]},index=['a','b','c'])

# %%
df
# Out:
#       Name  Marks
# a    Mehdi    100
# b  Murtaza      3
# c     Naqi      4

# %%
csv = pd.read_csv("Ciphertronix employee and hardware details.xlsx - Employees Info.csv")

# %%
csv.head(5)
# Out:
#   EMPLOYEES INFORMATION              Unnamed: 1          Unnamed: 2  \
# 0                   NaN                     NaN                 NaN
# 1         Serial Number                    Name       Date Of Birth
# 2                     1  Muhammad Shabaz Sharif  28th February 1980
# 3                     2              Ovais Khan     4th August 1996
# 4                     3       Syed Sibtain Raza  24th November 2000
#
#           Unnamed: 3   Unnamed: 4                     Unnamed: 5  \
# 0                NaN          NaN                            NaN
# 1        Father Name  Mother Name                       Email ID
# 2                NaN          NaN       Shahbaz@ciphertronix.com
# 3                NaN          NaN    ovais.khan@ciphertronix.com
# 4  Syed Raza Hussain          NaN  sibtain.raza@ciphertronix.com
#
#      Unnamed: 6       Unnamed: 7              Unnamed: 8 Unnamed: 9
# 0           NaN              NaN                     NaN        NaN
# ...

# %%
csv.tail(5)
# Out:
#    EMPLOYEES INFORMATION           Unnamed: 1  Unnamed: 2       Unnamed: 3  \
# 12                    11      Mohammad Hammad         NaN              NaN
# 13                    12         Zohair Rizvi         NaN              NaN
# 14                    13  Syed Zafaryab Abbas         NaN              NaN
# 15                    14       Moin UL Hassan         NaN              NaN
# 16                    15   Muhammad Ali Naqvi  28th March  Amjad Ali Naqvi
#
#        Unnamed: 4                  Unnamed: 5    Unnamed: 6 Unnamed: 7  \
# 12            NaN     mhammad352424@gmail.com  0342-2023191        NaN
# 13            NaN          Zohairpk@gmail.com  0333-2011181        NaN
# 14            NaN  muhammadzafaryab@gmail.com  0302-2710803        NaN
# 15            NaN         moinmono2@gmail.com  0322-6264804        NaN
# 16  Farzana Amjad  ali.naqvi@ciphertronix.com  0334-0765855        NaN
#
#    Unnamed: 8                                         Unnamed: 9
# ...

# %%
laptop = pd.read_csv("laptop.csv",encoding="latin1")

# %%
laptop
# Out:
#      Manufacturer                           Model Name            Category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#      Screen Size                                      Screen  \
# ...

# %%
laptop.shape
# Out:
# (1303, 13)

# %%
data = {
    "Name":['Mehdi','Abbas','Murtaza'],
    "Age":[17,17,15],
    "City":['Munich','Madrid','Karachi']
}

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
#       Name  Age     City
# 0    Mehdi   17   Munich
# 1    Abbas   17   Madrid
# 2  Murtaza   15  Karachi

# %%
data.to_csv("data.csv")
